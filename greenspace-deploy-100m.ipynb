# %% [markdown]
# ## Process data for 500m-buffer images
# The eval.py would downscale all images to 224x224 and generate corresponding masks for semantic segmentation. It would save 3 files to the `./tmp/Greenspace/result/` for each input image. For example, for input image `xxxx.png`, the eval.py would save a downscaled image `xxxx.png`, a image mask `xxxx_mask.png`, and a numpy format mask `xxxx_pred.npy`.

# %%
file_path   = './tmp/Greenspace/School_500m/'
result_path = './tmp/Greenspace/result/'

# %%
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
def display(img):
    _, ax = plt.subplots(1, 1, figsize=(8, 8))
    ax.imshow(img)
    ax.set_axis_off()

# %%
filename = "Adams,_Samuel_Elementary_.png"
display(np.asarray(Image.open(file_path + filename)))

# %%
import PIL
img = PIL.Image.open(file_path + filename)
img.size
# Out:
# (6824, 6825)

# %%
w, h = img.size
wNew = hNew = round(w / 5)
left = (w - wNew) / 2
top = (w - hNew) / 2
right = (w + wNew) / 2
bottom = (w + hNew) / 2
img = img.crop((left, top, right, bottom)).resize((224, 224))
img.size
# Out:
# (224, 224)

# %%
display(img)

# %% [markdown]
# Generate the result files by running the following code:

# %%
! python eval_100m.py semseg greenspace 0 SegForestNet MobileNetv2 --cpu
# Out:
# /projectnb/ds549/students/hjc5283/SegForestNet/python eval_100m.py semseg greenspace 0 SegForestNet MobileNetv2 --cpu
# parsing configuration file '/projectnb/ds549/students/hjc5283/SegForestNet/cfgs/semseg.yaml'
# sh: nvidia-smi: command not found
# num_classes 8
# i: 0 trees: namespace(num_features=namespace(shape=8, content=16), outputs=array([0, 1, 2, 3, 4, 5, 6, 7], dtype=int32), graph='BSPTree(2, Line)')
# tree_map (0, 0, 0, 0, 0, 0, 0, 0)
# Blackstone,_William_Eleme_pred
# Community_Academy_of_Scie_pred
# Curley_K8_Lower_School_50_pred
# Boston_Teachers_Union_K8__pred
# Grew,_Henry_Elementary_50_pred
# Channing,_William_E__Elem_pred
# Conley,_George_H__Element_pred
# Adams,_Samuel_Elementary__pred
# Boston_Latin_School_500m_pred
# Bradley,_Manassah_E__Elem_pred
# Boston_Green_Academy__500_pred
# Bates,_Phineas_Elementary_pred
# Boston_Day__Evening_Acade_pred
# Boston_Latin_Academy_500m_pred
# Another_Course_to_College_pred
# Bates,_Phineas_Eleme_1_pred
# Boston_International_Newc_pred
# Burke,_Jeremiah_E__High___pred
# Brighton_High_500m_pred
# Alighieri,_Dante_Montesso_pred
# Baldwin_Early_Learning_Pi_pred
# Young_Achievers_Science___pred
# Boston_Adult_Technical_Ac_pred
# Dorchester_Academy___1_pred
# Boston_Arts_Academy_500m_pred

# %% [markdown]
# Showing some of the results:

# %%
import matplotlib.pyplot as plt
from PIL import Image
import numpy as np
def displayResult(filename, filepath="./tmp/Greenspace/result/"):
    maskfile = ''.join([*filename.split('.')[:-1], '_mask.', *filename.split('.')[-1:]])
    fig, axs = plt.subplots(1, 2, figsize=(8, 16))
    axs[0].imshow(np.asarray(Image.open(filepath + filename)))
    axs[0].set_axis_off()
    axs[1].imshow(np.asarray(Image.open(filepath + maskfile)))
    axs[1].set_axis_off()
    fig.tight_layout()
    plt.show()

# %%
displayResult('Boston_Teachers_Union_K8_.png')

# %%
displayResult('Carter_Development_Center.png')

# %%
import math
import PIL.Image
import numpy as np
csv_file = 'school_100m_seg.csv'
notation = ["void","impervious_surface","building","low_vegetation","tree","car","water","sports_venues",]

# %%
def calculate(filename, result_path='./tmp/Greenspace/result/'):
    result_npy = ''.join([*filename.split('.')[:-1], '_pred.npy'])
    img = PIL.Image.open(result_path + filename)
    origin = np.asarray(img)[:,:,3] / 255
    pred   = np.load(result_path + result_npy)
    print(filename + ":")
    origin = origin.flatten()
    pred   = pred.flatten()
    total_pixel = origin.sum()
    count_pixel = [0] * len(notation)
    for i in range(len(notation)):
        count_pixel[i] += origin[np.where(pred == i)].sum()
    for i in range(len(notation)):
        count_pixel[i] = count_pixel[i] / total_pixel
        # print("%20s:%6.2f%%" % (notation[i], count_pixel[i]))
    return count_pixel

# %%
import os
all_files = os.listdir('./tmp/Greenspace/School_500m/')
len(all_files)
# Out:
# 133

# %%
import csv
with open(csv_file, 'w') as file:
    writer = csv.writer(file)
    writer.writerow(["School_Name", 
                     "Area_50m_Concrete_percent", "Area_50m_Concrete_sqm", 
                     "Area_50m_Building_percent", "Area_50m_Building_sqm", 
                     "Area_50m_LowVege_percent", "Area_50m_LowVege_sqm", 
                     "Area_50m_Tree_percent", "Area_50m_Tree_sqm", 
                     "Area_50m_Water_percent", "Area_50m_Water_sqm", ])
    for e in all_files:
        ratio = calculate(e)
        row = [''.join(e.split('.')[:-1]), ]
        for i in [1, 2, 3, 4, 6, ]:
            row.append(ratio[i] * 100.0)
            row.append(ratio[i] * 50 ** 2 * math.pi)
        writer.writerow(row)
# Out:
# Kennedy,_Patrick_Elementa.png:
# Ellis,_David_A__Elementar.png:
# Blackstone,_William_Eleme.png:
# Otis,_James_Elementary_50.png:
# Community_Academy_of_Scie.png:
# Curley_K8_Lower_School_50.png:
# Madison_Park_Technical_Vo.png:
# Boston_Green_Academy__50m.png:
# Boston_Teachers_Union_K8_.png:
# Horace_Mann_School_for_th.png:
# Mendell,_Ellis_Elementary.png:
# Beethoven,_Ludwig_Van_Ele.png:
# Mission_Hill_K8__50m.png:
# Jackson_Mann_K8__50m.png:
# Grew,_Henry_Elementary_50.png:
# Brighton_High_50m.png:
# Umana_Academy,_Mario_K8_5.png:
# Community_Academy_50m.png:
# Edwards,_Clarence_R__Midd.png:
# Kilmer,_Joyce_K8_Lower_Sc.png:
# West_Zone_Early_Learning_.png:
# Quincy,_Josiah_Upper_Scho.png:
# UP_Academy_Holland_50m.png:
# ODonnell,_Hugh_R__Element.png:
# Perkins,_Michael_J__Eleme.png:
# Quincy,_Josiah_Elementary.png:
# Channing,_William_E__Elem.png:
# Boston_Community_Leadersh.png:
# Philbrick,_John_D__Elemen.png:
# Hernandez,_Rafael_K8_50m.png:
# Harvard_Kent_Elementary_5.png:
# Ohrenberger,_William_H__K.png:
# Conley,_George_H__Element.png:
# Adams,_Samuel_Elementary_.png:
# Winthrop,_John_Elementary.png:
# Dorchester_Academy__50m.png:
# Higginson_Elementary_50m.png:
# Mildred_Avenue_K8_50m.png:
# Sumner,_Charles_Elementar.png:
# Mattahunt_Elementary_50m.png:
# Roosevelt,_Franklin_D__K8.png:
# Lee_Academy_at_the_Fifiel.png:
# UP_Academy_Dorchester_50m.png:
# Bradley,_Manassah_E__Elem.png:
# Kilmer,_Joyce_K8_Upper_Sc.png:
# Chittick,_James_J__Elemen.png:
# Murphy,_Richard_K8_50m.png:
# Snowden_International_Sch.png:
# Frederick,_Lilla_G__Middl.png:
# Lyndon,_Patrick_K8_50m.png:
# Irving,_Washington_Middle.png:
# Guild,_Curtis_Elementary_.png:
# McKay,_Donald_K8_50m.png:
# Higginson_Lewis_K8_50m.png:
# Timilty,_James_P__Middle_.png:
# Trotter,_William_Monroe_K.png:
# Bates,_Phineas_Elementary.png:
# Curley_K8_Upper_School_50.png:
# Gardner_Pilot_Academy_K8_.png:
# Kenny,_Thomas_J__Elementa.png:
# Hurley,_Joseph_K8_50m.png:
# Carter_Development_Center.png:
# Edison,_Thomas_A__K8_50m.png:
# OBryant,_John_D__School_o.png:
# Eliot,_John_K8_Lower_Scho.png:
# Stone,_Lucy_Elementary_50.png:
# Muniz,_Margarita_Academy_.png:
# Dever,_Paul_A__Elementary.png:
# Charlestown_High_50m.png:
# Orchard_Gardens_K8_50m.png:
# Warren_Prescott_K8_Lower_.png:
# Rogers_Middle_School_50m.png:
# Henderson,_Dr__William_W_.png:
# Mason,_Samuel_W__Elementa.png:
# Winship,_F__Lyman_Element.png:
# Boston_Day__Evening_Acade.png:
# West_Roxbury_Academy__50m.png:
# McKinley_Middle_50m.png:
# Boston_Latin_School_50m.png:
# Haley_K__8,_Dennis_50m.png:
# Greenwood,_Elihu_Leadersh.png:
# Another_Course_to_College.png:
# English_High,_The_50m.png:
# McCormack,_John_W_Middle_.png:
# Hamilton,_Alexander_50m.png:
# Urban_Science_Academy__50.png:
# Dickerman_Elementary_50m.png:
# Greater_Egleston_Communit.png:
# Haynes_Early_Education_Ce.png:
# Mather_Elementary_50m.png:
# UP_Academy_Boston_50m.png:
# Ellison_Parks_Early_Educa.png:
# East_Boston_High_50m.png:
# Boston_International_Newc.png:
# Warren_Prescott_K8_Upper_.png:
# Lyon,_Mary_K8_50m.png:
# Lyon,_Mary_High_50m.png:
# TechBoston_Academy_50m.png:
# McKinley,_Wm__Preparatory.png:
# McKinley,_Wm_So__End_Acad.png:
# Manning,_Joseph_P__Elemen.png:
# Boston_Latin_Academy_50m.png:
# Tynan,_Joseph_P__Elementa.png:
# Hennigan,_James_W__K8__50.png:
# East_Boston_Early_Educati.png:
# Burke,_Jeremiah_E__High__.png:
# Kennedy,_Edward_M__Academ.png:
# Eliot,_John_K8_Upper_Scho.png:
# Condon,_James_F__Elementa.png:
# Hale,_Nathan_Elementary_5.png:
# Tobin,_Maurice_J__K8_50m.png:
# Mozart,_Wolfgang_A__Eleme.png:
# Everett,_Edwards_Elementa.png:
# Boston_Arts_Academy_50m.png:
# Fenway_High_50m.png:
# Endicott_50m.png:
# King,_Martin_Luther,_Jr_K.png:
# Kennedy,_John_F_Elementar.png:
# Shaw,_Pauline_A__Elementa.png:
# New_Mission_High__50m.png:
# Quincy,_Josiah_Upper_Modu.png:
# Dudley_Street_Neighborhoo.png:
# Excel_High_50m.png:
# Alighieri,_Dante_Montesso.png:
# Lee,_Joseph_K8_50m.png:
# Taylor,_Charles_H__Elemen.png:
# Clap_Innovation_School_50.png:
# Baldwin_Early_Learning_Pi.png:
# Young_Achievers_Science__.png:
# Dearborn_STEM_Academy__50.png:
# Boston_Adult_Technical_Ac.png:
# Russell,_William_E__Eleme.png:
# Holmes,_Oliver_Wendell_El.png:

# %%
import pandas as pd
df = pd.read_csv(csv_file)
df.head()
# Out:
#                  School_Name  Area_50m_Concrete_percent  \
# 0  Kennedy,_Patrick_Elementa                  51.353872
# 1  Ellis,_David_A__Elementar                  42.673967
# 2  Blackstone,_William_Eleme                  38.862666
# 3  Otis,_James_Elementary_50                  44.975342
# 4  Community_Academy_of_Scie                  45.677275
#
#    Area_50m_Concrete_sqm  Area_50m_Building_percent  Area_50m_Building_sqm  \
# 0            4033.323642                  24.039889            1888.088459
# 1            3351.605550                  21.292372            1672.298949
# 2            3052.266631                  24.737393            1942.870282
# 3            3532.355066                  28.053452            2203.312993
# 4            3587.484817                  26.534471            2084.012453
#
#    Area_50m_LowVege_percent  Area_50m_LowVege_sqm  Area_50m_Tree_percent  \
# 0                  5.207927            409.029607              15.473146
# 1                 13.428550           1054.675839              19.391205
# 2                 13.238130           1039.720274              17.907136
# 3                  6.243295            490.347262              15.632192
# 4                  7.153933            561.868603              14.955684
#
#    Area_50m_Tree_sqm  Area_50m_Water_percent  Area_50m_Water_sqm
# 0        1215.258023                     0.0                 0.0
# 1        1522.981689                     0.0                 0.0
# 2        1406.423145                     0.0                 0.0
# 3        1227.749465                     0.0                 0.0
# 4        1174.616659                     0.0                 0.0
